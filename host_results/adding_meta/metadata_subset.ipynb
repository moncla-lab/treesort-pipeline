# %%
import pandas as pd
import os
import sys
import numpy as np
import re

module_dir = "/Users/monclalab1/Documents/scripts/"
sys.path.append(module_dir)

from fasta_editing import fasta_to_df, fasta_writer

# %%
species = pd.read_csv("classifications/species.csv")
flyway = pd.read_csv("classifications/flyway.csv")
meta = pd.read_csv("meta/metadata.csv")

# %%
meta['region'] = meta['region'].str.lower()
meta['host'] = meta['host'].str.lower()
flyway['location'] = flyway['location'].str.lower()

# %%
df_avian = meta.loc[
    (meta['region'] == 'north america') & (meta['host'] == 'avian')
].copy()

# %%
df_avian['updated_species'] = df_avian['strain'].str.lower().str.split("/").str[1]
df_avian = df_avian.dropna(subset=['species'])
df_avian = df_avian.drop(columns=['broad'])

# %%
species['annotated'] = species['annotated'].str.lower()

df_avian = df_avian.merge(
    species[['annotated', 'correction', 'order', 'broad']],
    left_on='updated_species',
    right_on='annotated',
    how='left'
).copy()


# # Optional: drop helper columns from merge
# df_avian = df_avian.drop(columns=['annotated', 'correction', 'order_y'])
# df_avian = df_avian.rename(columns={'order_x': 'order'})

# %%
df_avian['species'] = df_avian['correction'].str.lower()
df_avian['order'] = df_avian['order_y'].str.lower() 
df_avian = df_avian.drop(columns=['updated_species', 'annotated', 'correction', 'order_y', 'order_x'])
df_avian
# Out:
#                                                  strain   accession subtype  \
# 0     A/American_black_duck/Alberta/284/2016|2016-08-28    MG599652    H3N8
# 1      A/American_black_duck/Alberta/96/2016|2016-08-11    MF613845    H3N6
# 2     A/American_black_duck/Maine/44411/532/2008|200...    KP636478    H3N8
# 3     A/American_Black_Duck/Maine/A00090256/2007|200...    MN210123    H3N2
# 4     A/American_black_duck/Maine/ME-Y17-170/2017|20...  EPI1774726    H3N8
# ...                                                 ...         ...     ...
# 2218          A/wood_duck/Ohio/13OS3300/2013|2013-10-12    KJ568401    H3N8
# 2219  A/Wood_Duck/South_Dakota/A00605524/2008|2008-0...    OQ987893    H3N8
# 2220     A/wood_duck/Wisconsin/10OS2778/2010|2010-09-26    CY132957    H3N8
# 2221     A/wood_duck/Wisconsin/11OS2912/2011|2011-09-24    CY167110    H3N6
# 2222          A/wood_duck/Wisconsin/158/1980|1980-01-01    CY180916    H3N2
#
#             date   host country         region              species broad  \
# 0     2016-08-28  avian  Canada  north america  american_black_duck  duck
# 1     2016-08-11  avian  Canada  north america  american_black_duck  duck
# 2     2008-01-01  avian     Usa  north america  american_black_duck  duck
# 3     2007-09-25  avian     Usa  north america  american_black_duck  duck
# 4     2017-08-29  avian     Usa  north america  american_black_duck  duck
# ...          ...    ...     ...            ...                  ...   ...
# 2218  2013-10-12  avian     Usa  north america            wood_duck  duck
# 2219  2008-08-18  avian     Usa  north america            wood_duck  duck
# 2220  2010-09-26  avian     Usa  north america            wood_duck  duck
# 2221  2011-09-24  avian     Usa  north america            wood_duck  duck
# 2222  1980-01-01  avian     Usa  north america            wood_duck  duck
#
#              order
# 0     anseriformes
# 1     anseriformes
# 2     anseriformes
# 3     anseriformes
# 4     anseriformes
# ...            ...
# 2218  anseriformes
# 2219  anseriformes
# 2220  anseriformes
# 2221  anseriformes
# 2222  anseriformes
#
# [2223 rows x 10 columns]

# %%
df_avian['state'] = df_avian['strain'].str.lower().str.split("/").str[2]

# %%
df_avian['state'].unique()
# Out:
# array(['alberta', 'maine', 'new_brunswick', 'new_hampshire',
#        'newfoundland', 'newfoundland_and_labrador', 'north_carolina',
#        'nova_scotia', 'ohio', 'prince_edward_island', 'quebec',
#        "st._john's", 'washington', 'oregon', '17os4133', 'alaska',
#        'idaho', 'illinois', 'interior_alaska', 'mississippi', 'missouri',
#        'montana', 'north_dakota', 'texas', 'wisconsin', 'minnesota',
#        'utah', 'new_mexico', 'arizona', 'alb', 'canada', 'guatemala',
#        'iowa', 'kansas', 'louisiana', 'lousiana', 'manitoba', 'mexico',
#        'saskatchewan', 'south_dakota', 'ny', 'california', 'la',
#        'memohis', 'memphis', 'ontario', 'southcentral_alaska', 'michigan',
#        'nj', 'new_jersey', 'delaware_bay', 'maryland', '708', 'ab',
#        'arkansas', 'bc', 'british_columbia', 'mn', 'nevada', 'new_york',
#        'pennsylvania', 'vermont', 'delaware', 'barrow', 'qc', 'georgia',
#        'south_carolina', 'nunavet', '_minnesota', 'canada-bc',
#        'canada-manitoba', 'canada-ontario', 'nc', 'oh'], dtype=object)

# %%
merged = df_avian.merge(
    flyway[['location', 'flyway']],
    left_on='state',
    right_on='location',
    how='left'
)

# %%
merged
# Out:
#                                                  strain   accession subtype  \
# 0     A/American_black_duck/Alberta/284/2016|2016-08-28    MG599652    H3N8
# 1      A/American_black_duck/Alberta/96/2016|2016-08-11    MF613845    H3N6
# 2     A/American_black_duck/Maine/44411/532/2008|200...    KP636478    H3N8
# 3     A/American_Black_Duck/Maine/A00090256/2007|200...    MN210123    H3N2
# 4     A/American_black_duck/Maine/ME-Y17-170/2017|20...  EPI1774726    H3N8
# ...                                                 ...         ...     ...
# 2231          A/wood_duck/Ohio/13OS3300/2013|2013-10-12    KJ568401    H3N8
# 2232  A/Wood_Duck/South_Dakota/A00605524/2008|2008-0...    OQ987893    H3N8
# 2233     A/wood_duck/Wisconsin/10OS2778/2010|2010-09-26    CY132957    H3N8
# 2234     A/wood_duck/Wisconsin/11OS2912/2011|2011-09-24    CY167110    H3N6
# 2235          A/wood_duck/Wisconsin/158/1980|1980-01-01    CY180916    H3N2
#
#             date   host country         region              species broad  \
# 0     2016-08-28  avian  Canada  north america  american_black_duck  duck
# 1     2016-08-11  avian  Canada  north america  american_black_duck  duck
# 2     2008-01-01  avian     Usa  north america  american_black_duck  duck
# 3     2007-09-25  avian     Usa  north america  american_black_duck  duck
# 4     2017-08-29  avian     Usa  north america  american_black_duck  duck
# ...          ...    ...     ...            ...                  ...   ...
# 2231  2013-10-12  avian     Usa  north america            wood_duck  duck
# 2232  2008-08-18  avian     Usa  north america            wood_duck  duck
# 2233  2010-09-26  avian     Usa  north america            wood_duck  duck
# 2234  2011-09-24  avian     Usa  north america            wood_duck  duck
# 2235  1980-01-01  avian     Usa  north america            wood_duck  duck
#
#              order         state      location              flyway
# 0     anseriformes       alberta       alberta      central_flyway
# 1     anseriformes       alberta       alberta      central_flyway
# 2     anseriformes         maine         maine     atlantic_flyway
# 3     anseriformes         maine         maine     atlantic_flyway
# 4     anseriformes         maine         maine     atlantic_flyway
# ...            ...           ...           ...                 ...
# 2231  anseriformes          ohio          ohio  mississippi_flyway
# 2232  anseriformes  south_dakota  south_dakota      central_flyway
# 2233  anseriformes     wisconsin     wisconsin  mississippi_flyway
# 2234  anseriformes     wisconsin     wisconsin  mississippi_flyway
# 2235  anseriformes     wisconsin     wisconsin  mississippi_flyway
#
# [2236 rows x 13 columns]

# %%
merged['order'].value_counts()
# Out:
# order
# anseriformes       1972
# charadriiformes     173
# avian                50
# galliformes          39
# neoave                2
# Name: count, dtype: int64

# %%
merged['broad'].value_counts()
# Out:
# broad
# duck           1950
# wader           162
# avian            50
# turkey           36
# goose            22
# gull             11
# coot              1
# chicken           1
# cormorant         1
# guinea_fowl       1
# quail             1
# Name: count, dtype: int64

# %%
merged = merged.drop_duplicates(subset=["strain"])
merged.to_csv("meta/meta.csv", index=False)
