# %%
import baltic as bt
import pandas as pd
import numpy as np
import json
import os
import matplotlib.pyplot as plt
import itertools
from collections import defaultdict
import statistics
import numpy as np
from scipy.optimize import minimize, LinearConstraint
import warnings
from datetime import datetime
import re
from treetime import TreeTime, TreeTimeError, utils
from dendropy import Tree
from Bio import SeqIO
import random
import math
import scipy.stats as stats

# %%
clades = ['h3nx', 'na_avian', 'swine', 'human', 'equine', 'canine']

# %%
host_trees = {}

for clade in clades:
    
    path = f'{clade}/treesort.json'
    mytree, mymeta = bt.loadJSON(path, json_translation={'name':'name','absoluteTime':'div'})

    with open(f"{clade}/node.json", "r") as f:
        rea = json.load(f)
    
    host_trees[clade] = {
    f'{clade}_tree': mytree,
    f'{clade}_rea': rea
    }

for clade in clades:
    
    values = list(host_trees[clade].values())
    mytree, rea = values 

    for k in mytree.Objects:

        if k.name in rea["nodes"]:
            k.traits['reassorted'] = True
            k.traits['segment'] = rea["nodes"][k.name]['reassortment_events']

        else:
            k.traits['reassorted'] = False
            k.traits['segment'] = None
# Out:
# Tree height: 0.419000
# Tree length: 26.050100
# multitype tree
# annotations present
#
# Numbers of objects in tree: 9467 (4206 nodes and 5261 leaves)
#
#
# Tree height: 0.130730
# Tree length: 3.825850
# strictly bifurcating tree
# annotations present
#
# Numbers of objects in tree: 2387 (1193 nodes and 1194 leaves)
#
#
# Tree height: 0.276270
# Tree length: 11.773940
# strictly bifurcating tree
# annotations present
#
# Numbers of objects in tree: 4031 (2015 nodes and 2016 leaves)
#
#
# Tree height: 0.216980
# Tree length: 0.958310
# strictly bifurcating tree
# annotations present
#
# Numbers of objects in tree: 469 (234 nodes and 235 leaves)
#
#
# Tree height: 0.125560
# Tree length: 0.577050
# strictly bifurcating tree
# annotations present
#
# Numbers of objects in tree: 447 (223 nodes and 224 leaves)
#
#
# Tree height: 0.039220
# Tree length: 0.438800
# strictly bifurcating tree
# annotations present
#
# Numbers of objects in tree: 849 (424 nodes and 425 leaves)

# %%
def parse_dates(aln_path: str):
    records = SeqIO.parse(aln_path, 'fasta')
    dates = {}
    for record in records:
        name = record.name
        # date_str = name.split('|')[-1]
        date = None
        for token in name.split('|'):
            if re.fullmatch(r'[\d\-/]{4,}', token) and not re.fullmatch(r'\d{5,}', token):
                if token.count('/') == 2:
                    date = datetime.strptime(token, '%m/%d/%Y')
                elif token.count('/') == 1:
                    date = datetime.strptime(token, '%m/%Y')
                elif token.count('-') == 2:
                    date = datetime.strptime(token, '%Y-%m-%d')
                elif token.count('-') == 1:
                    date = datetime.strptime(token, '%Y-%m')
                else:
                    date = datetime.strptime(token, '%Y')
        if not date:
            pass
        else:
            dec_date = date.year + ((date.month - 1) * 30 + date.day) / 365.0
            dates[name] = dec_date
    return dates

def estimate_clock_rate(tree_path: str, aln_path: str, outdir='.') -> (float, float):
    
    # This code was adapted from the  'estimate_clock_model' method in the treetime/wrappers.py.
    tree: Tree = Tree.get(path=tree_path, schema='newick', preserve_underscores=True)
    if len(tree.leaf_nodes()) > 1000:
        tree_path = os.path.join(outdir, os.path.split(tree_path)[-1] + '.sample1k.tre')
        taxa_labels = [t.label for t in tree.taxon_namespace]
        random.shuffle(taxa_labels)
        subtree: Tree = tree.extract_tree_with_taxa_labels(taxa_labels[:1000])
        subtree.write(path=tree_path, schema='newick')

    dates = parse_dates(aln_path)
    
    timetree = TreeTime(dates=dates, tree=tree_path, aln=aln_path, gtr='JC69', verbose=-1)  # TODO: JC->GTR?
          
    timetree.clock_filter(n_iqd=3, reroot='least-squares')
    timetree.use_covariation = True
    timetree.reroot()
    timetree.get_clock_model(covariation=True)
    
    # trying to get root here, but it changes quite unstably from inference to inference
    # should i resolve polytomies?
    timetree.run(root='least-squares', resolve_polytomies=True)

    inferred_root_date = timetree.tree.root.numdate
    print(f"inferred root date: {inferred_root_date:.4f}")

    r_val = timetree.clock_model['r_val']
    
    d2d = utils.DateConversion.from_regression(timetree.clock_model)
    clock_rate = round(d2d.clock_rate, 7)
    
    return d2d.clock_rate, r_val, inferred_root_date

# %%
host_stats = {}

for clade in clades:
    
    clock_rate, r_val, root_yr = estimate_clock_rate(f"{clade}/summary.nwk", f"{clade}/h3nx_ha.fasta")
    
    host_stats[clade] = {
    'clock_rate': clock_rate,
    'root_yr': root_yr
    }
# Out:
# inferred root date: 1922.4375
# inferred root date: 1930.7730
# inferred root date: 1968.4751
# inferred root date: 1967.2012
# inferred root date: 1954.6612
# inferred root date: 2004.4306

# %%
print(host_stats)
# Out:
# {'h3nx': {'clock_rate': 0.002196424515674057, 'root_yr': 1922.4375179899985}, 'na_avian': {'clock_rate': 0.001374273170154074, 'root_yr': 1930.7729725242664}, 'swine': {'clock_rate': 0.00402553323860504, 'root_yr': 1968.475084116971}, 'human': {'clock_rate': 0.003972473989812167, 'root_yr': 1967.2011790334825}, 'equine': {'clock_rate': 0.001889978312793038, 'root_yr': 1954.661201042591}, 'canine': {'clock_rate': 0.00226857861002214, 'root_yr': 2004.430550844031}}

# %% [markdown]
# # 10 years

# %%
current_year = 2025
fit_time = 10

node_rea_counts = {clade: {} for clade in host_trees.keys()}
leaf_rea_counts = {clade: {} for clade in host_trees.keys()}

node_counts = {clade: {} for clade in host_trees.keys()}
leaf_counts = {clade: {} for clade in host_trees.keys()}

rea_fits = {clade: {} for clade in host_trees.keys()}
clonal_fits = {clade: {} for clade in host_trees.keys()}
rea_unfits = {clade: {} for clade in host_trees.keys()}
clonal_unfits = {clade: {} for clade in host_trees.keys()}


for clade in clades:
    
    mytree, rea = list(host_trees[clade].values()) 

    node_count = node_rea_count = leaf_count = leaf_rea_count= 0

    rea_fit = clonal_fit = rea_unfit = clonal_unfit = 0

    mytree.traverse_tree()  
    mytree.sortBranches()

    leaf_heights = {}

    for leaf in mytree.getExternal():

        leaf_heights[leaf.name] = (leaf.height, leaf.name.split("|")[1])


    for k in mytree.Objects:

        # for the fisher's exact test

        if k.is_leaf():

            leaf_count += 1

            if k.traits.get('reassorted'):

                leaf_rea_count += 1

        elif k.is_node():

            node_count += 1

            if k.traits.get('reassorted'):

                node_rea_count += 1

            # for the lineage fitness analysis

            # excluding nodes that are less than 2 years old 

            if (k.height / clock_rate) >= (current_year - host_stats[clade]['root_yr']) - fit_time:
                continue

            # which is correct? 

            # 1. find the leaf with the highest root to tip divergence (height) 
            # then subtract the current node's height from that leafs height

            # leaf_height = max(leaf_heights[leaf][0] for leaf in k.leaves)

            # 2. find the tip with the latest date and subtract the current node's height from that leafs height

            dates_and_heights = [(leaf_heights[leaf][1], leaf_heights[leaf][0]) for leaf in k.leaves]

            max_date, leaf_height = max(dates_and_heights, key=lambda x: x[0])

            date = (leaf_height - k.height) / clock_rate

            # date = int(max_date[:4]) - ((k.height / clock_rate) + root_yr)

            if date > fit_time:

                if k.traits.get('reassorted'):
                    rea_fit += 1

                else:
                    clonal_fit += 1     

            else:

                if k.traits.get('reassorted'):
                    rea_unfit += 1

                else:
                    clonal_unfit += 1
                    
        node_counts[clade] = node_count
        leaf_counts[clade] = leaf_count

        node_rea_counts[clade] = node_rea_count
        leaf_rea_counts[clade] = leaf_rea_count


        rea_fits[clade] = rea_fit
        clonal_fits[clade] = clonal_fit

        rea_unfits[clade] = rea_unfit
        clonal_unfits[clade] = clonal_unfit

# %%
print(rea_fits)
print(clonal_fits)

print(rea_unfits)
print(clonal_unfits)
# Out:
# {'h3nx': 44, 'na_avian': 19, 'swine': 4, 'human': 0, 'equine': 0, 'canine': 0}
# {'h3nx': 245, 'na_avian': 99, 'swine': 28, 'human': 32, 'equine': 45, 'canine': 16}
# {'h3nx': 419, 'na_avian': 247, 'swine': 3, 'human': 3, 'equine': 2, 'canine': 2}
# {'h3nx': 1202, 'na_avian': 828, 'swine': 22, 'human': 105, 'equine': 176, 'canine': 211}

# %%
# fitness analysis FET

p_values = []
odds_ratios = []
confidence = []


for clade in clades:
    a = rea_fits[clade]
    b = clonal_fits[clade]
    c = rea_unfits[clade]
    d = clonal_unfits[clade]

    table = [[a, b], [c, d]]

    odds_ratio, p_value = stats.fisher_exact(table, alternative='two-sided')

    if a > 0 and b > 0 and c > 0 and d > 0:
        se_log_or = math.sqrt(1/a + 1/b + 1/c + 1/d)
        log_or = math.log(odds_ratio)
        ci_low = math.exp(log_or - 1.96 * se_log_or)
        ci_high = math.exp(log_or + 1.96 * se_log_or)
    else:
        print(f"one of your counts for {clade} are 0")
        ci_low, ci_high = float('nan'), float('nan')
        
    odds_ratios.append(odds_ratio)
    p_values.append(p_value)
    confidence.append((ci_low, ci_high))

    print(f"{clade}: p-value = {p_value:.6f}, odds ratio = {odds_ratio:.2f}, 95% CI = {ci_low, ci_high}")
# Out:
# h3nx: p-value = 0.000073, odds ratio = 0.52, 95% CI = (0.3668380436212149, 0.7235685884222479)
# na_avian: p-value = 0.102495, odds ratio = 0.64, 95% CI = (0.3859220740734143, 1.0725164440124488)
# swine: p-value = 1.000000, odds ratio = 1.05, 95% CI = (0.21199062496182103, 5.177142475672678)
# one of your counts for human are 0
# human: p-value = 1.000000, odds ratio = 0.00, 95% CI = (nan, nan)
# one of your counts for equine are 0
# equine: p-value = 1.000000, odds ratio = 0.00, 95% CI = (nan, nan)
# one of your counts for canine are 0
# canine: p-value = 1.000000, odds ratio = 0.00, 95% CI = (nan, nan)

# %%
num_clades = len(clades)
fig, axes = plt.subplots(1, num_clades, figsize=(num_clades * 3, 6), sharey=True)

for ax, clade, odds_ratio, p_value, (ci_low, ci_high) in zip(
        axes, clades, odds_ratios, p_values, confidence):

    #  error bars
    lower_err = odds_ratio - ci_low
    upper_err = ci_high - odds_ratio
    error_bars = [[lower_err], [upper_err]]

    ax.errorbar(
        [0], [odds_ratio],
        yerr=error_bars,
        fmt='o',
        color='darkcyan',
        ecolor='darkgrey',
        elinewidth=2,
        capsize=4,
        markersize=10
    )

    ax.axhline(1, color='black', linestyle='--')

    ax.set_xticks([0])
    ax.set_xticklabels([clade], rotation=45, ha='right')
    ax.set_xlim(-1, 1)

    ax.legend([f"p = {p_value:.8f}"], loc='upper right', frameon=False)

axes[0].set_ylabel("Odds Ratio")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 6 years

# %%
current_year = 2025
fit_time = 6

node_rea_counts = {clade: {} for clade in host_trees.keys()}
leaf_rea_counts = {clade: {} for clade in host_trees.keys()}

node_counts = {clade: {} for clade in host_trees.keys()}
leaf_counts = {clade: {} for clade in host_trees.keys()}

rea_fits = {clade: {} for clade in host_trees.keys()}
clonal_fits = {clade: {} for clade in host_trees.keys()}
rea_unfits = {clade: {} for clade in host_trees.keys()}
clonal_unfits = {clade: {} for clade in host_trees.keys()}


for clade in clades:
    
    mytree, rea = list(host_trees[clade].values()) 

    node_count = node_rea_count = leaf_count = leaf_rea_count= 0

    rea_fit = clonal_fit = rea_unfit = clonal_unfit = 0

    mytree.traverse_tree()  
    mytree.sortBranches()

    leaf_heights = {}

    for leaf in mytree.getExternal():

        leaf_heights[leaf.name] = (leaf.height, leaf.name.split("|")[1])


    for k in mytree.Objects:

        # for the fisher's exact test

        if k.is_leaf():

            leaf_count += 1

            if k.traits.get('reassorted'):

                leaf_rea_count += 1

        elif k.is_node():

            node_count += 1

            if k.traits.get('reassorted'):

                node_rea_count += 1

            # for the lineage fitness analysis

            # excluding nodes that are less than 2 years old 

            if (k.height / clock_rate) >= (current_year - host_stats[clade]['root_yr']) - fit_time:
                continue

            # which is correct? 

            # 1. find the leaf with the highest root to tip divergence (height) 
            # then subtract the current node's height from that leafs height

            # leaf_height = max(leaf_heights[leaf][0] for leaf in k.leaves)

            # 2. find the tip with the latest date and subtract the current node's height from that leafs height

            dates_and_heights = [(leaf_heights[leaf][1], leaf_heights[leaf][0]) for leaf in k.leaves]

            max_date, leaf_height = max(dates_and_heights, key=lambda x: x[0])

            date = (leaf_height - k.height) / clock_rate

            # date = int(max_date[:4]) - ((k.height / clock_rate) + root_yr)

            if date > fit_time:

                if k.traits.get('reassorted'):
                    rea_fit += 1

                else:
                    clonal_fit += 1     

            else:

                if k.traits.get('reassorted'):
                    rea_unfit += 1

                else:
                    clonal_unfit += 1
                    
        node_counts[clade] = node_count
        leaf_counts[clade] = leaf_count

        node_rea_counts[clade] = node_rea_count
        leaf_rea_counts[clade] = leaf_rea_count


        rea_fits[clade] = rea_fit
        clonal_fits[clade] = clonal_fit

        rea_unfits[clade] = rea_unfit
        clonal_unfits[clade] = clonal_unfit

# %%
print(rea_fits)
print(clonal_fits)

print(rea_unfits)
print(clonal_unfits)
# Out:
# {'h3nx': 88, 'na_avian': 39, 'swine': 5, 'human': 1, 'equine': 0, 'canine': 0}
# {'h3nx': 388, 'na_avian': 172, 'swine': 37, 'human': 38, 'equine': 58, 'canine': 35}
# {'h3nx': 387, 'na_avian': 227, 'swine': 4, 'human': 2, 'equine': 2, 'canine': 3}
# {'h3nx': 1112, 'na_avian': 755, 'swine': 34, 'human': 104, 'equine': 163, 'canine': 296}

# %%
# fitness analysis FET

p_values = []
odds_ratios = []
confidence = []


for clade in clades:
    a = rea_fits[clade]
    b = clonal_fits[clade]
    c = rea_unfits[clade]
    d = clonal_unfits[clade]

    table = [[a, b], [c, d]]

    odds_ratio, p_value = stats.fisher_exact(table, alternative='two-sided')

    if a > 0 and b > 0 and c > 0 and d > 0:
        se_log_or = math.sqrt(1/a + 1/b + 1/c + 1/d)
        log_or = math.log(odds_ratio)
        ci_low = math.exp(log_or - 1.96 * se_log_or)
        ci_high = math.exp(log_or + 1.96 * se_log_or)
    else:
        print(f"one of your counts for {clade} are 0")
        ci_low, ci_high = float('nan'), float('nan')
        
    odds_ratios.append(odds_ratio)
    p_values.append(p_value)
    confidence.append((ci_low, ci_high))

    print(f"{clade}: p-value = {p_value:.6f}, odds ratio = {odds_ratio:.2f}, 95% CI = {ci_low, ci_high}")
# Out:
# h3nx: p-value = 0.001085, odds ratio = 0.65, 95% CI = (0.5031336965356036, 0.8441237762538596)
# na_avian: p-value = 0.171208, odds ratio = 0.75, 95% CI = (0.516789931005308, 1.100526401571034)
# swine: p-value = 1.000000, odds ratio = 1.15, 95% CI = (0.28472305942669796, 4.6339545546434575)
# human: p-value = 1.000000, odds ratio = 1.37, 95% CI = (0.12058225168841674, 15.529451068172412)
# one of your counts for equine are 0
# equine: p-value = 1.000000, odds ratio = 0.00, 95% CI = (nan, nan)
# one of your counts for canine are 0
# canine: p-value = 1.000000, odds ratio = 0.00, 95% CI = (nan, nan)

# %%
for clade, odds_ratio, p_value, (ci_low, ci_high) in zip(clades, odds_ratios, p_values, confidence):
    plt.figure(figsize=(4, 6))

    plt.errorbar(
        x=0,
        y=odds_ratio,
        yerr=[[odds_ratio - ci_low], [ci_high - odds_ratio]],
        fmt='o',
        color='tab:blue',
        capsize=5,
        label=f'p = {p_value:.5f}'
    )

    plt.axhline(1, color='gray', linestyle='--')  # neutral OR
    plt.xticks([0], [clade])  # show label on x-axis
    plt.ylabel('Odds Ratio')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
num_clades = len(clades)
fig, axes = plt.subplots(1, num_clades, figsize=(num_clades * 3, 6), sharey=True)

for ax, clade, odds_ratio, p_value, (ci_low, ci_high) in zip(
        axes, clades, odds_ratios, p_values, confidence):

    #  error bars
    lower_err = odds_ratio - ci_low
    upper_err = ci_high - odds_ratio
    error_bars = [[lower_err], [upper_err]]

    ax.errorbar(
        [0], [odds_ratio],
        yerr=error_bars,
        fmt='o',
        color='darkcyan',
        ecolor='darkgrey',
        elinewidth=2,
        capsize=4,
        markersize=10
    )

    ax.axhline(1, color='black', linestyle='--')

    ax.set_xticks([0])
    ax.set_xticklabels([clade], rotation=45, ha='right')
    ax.set_xlim(-1, 1)

    ax.legend([f"p = {p_value:.3f}"], loc='upper right', frameon=False)

axes[0].set_ylabel("Odds Ratio")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 1 year

# %%
current_year = 2025
fit_time = 1

node_rea_counts = {clade: {} for clade in host_trees.keys()}
leaf_rea_counts = {clade: {} for clade in host_trees.keys()}

node_counts = {clade: {} for clade in host_trees.keys()}
leaf_counts = {clade: {} for clade in host_trees.keys()}

rea_fits = {clade: {} for clade in host_trees.keys()}
clonal_fits = {clade: {} for clade in host_trees.keys()}
rea_unfits = {clade: {} for clade in host_trees.keys()}
clonal_unfits = {clade: {} for clade in host_trees.keys()}


for clade in clades:
    
    mytree, rea = list(host_trees[clade].values()) 

    node_count = node_rea_count = leaf_count = leaf_rea_count= 0

    rea_fit = clonal_fit = rea_unfit = clonal_unfit = 0

    mytree.traverse_tree()  
    mytree.sortBranches()

    leaf_heights = {}

    for leaf in mytree.getExternal():

        leaf_heights[leaf.name] = (leaf.height, leaf.name.split("|")[1])


    for k in mytree.Objects:

        # for the fisher's exact test

        if k.is_leaf():

            leaf_count += 1

            if k.traits.get('reassorted'):

                leaf_rea_count += 1

        elif k.is_node():

            node_count += 1

            if k.traits.get('reassorted'):

                node_rea_count += 1

            # for the lineage fitness analysis

            # excluding nodes that are less than 2 years old 

            if (k.height / clock_rate) >= (current_year - host_stats[clade]['root_yr']) - fit_time:
                continue

            # which is correct? 

            # 1. find the leaf with the highest root to tip divergence (height) 
            # then subtract the current node's height from that leafs height

            # leaf_height = max(leaf_heights[leaf][0] for leaf in k.leaves)

            # 2. find the tip with the latest date and subtract the current node's height from that leafs height

            dates_and_heights = [(leaf_heights[leaf][1], leaf_heights[leaf][0]) for leaf in k.leaves]

            max_date, leaf_height = max(dates_and_heights, key=lambda x: x[0])

            date = (leaf_height - k.height) / clock_rate

            # date = int(max_date[:4]) - ((k.height / clock_rate) + root_yr)

            if date > fit_time:

                if k.traits.get('reassorted'):
                    rea_fit += 1

                else:
                    clonal_fit += 1     

            else:

                if k.traits.get('reassorted'):
                    rea_unfit += 1

                else:
                    clonal_unfit += 1
                    
        node_counts[clade] = node_count
        leaf_counts[clade] = leaf_count

        node_rea_counts[clade] = node_rea_count
        leaf_rea_counts[clade] = leaf_rea_count


        rea_fits[clade] = rea_fit
        clonal_fits[clade] = clonal_fit

        rea_unfits[clade] = rea_unfit
        clonal_unfits[clade] = clonal_unfit

# %%
print(rea_fits)
print(clonal_fits)

print(rea_unfits)
print(clonal_unfits)
# Out:
# {'h3nx': 246, 'na_avian': 125, 'swine': 9, 'human': 3, 'equine': 1, 'canine': 1}
# {'h3nx': 781, 'na_avian': 411, 'swine': 75, 'human': 100, 'equine': 120, 'canine': 97}
# {'h3nx': 234, 'na_avian': 141, 'swine': 4, 'human': 0, 'equine': 1, 'canine': 2}
# {'h3nx': 751, 'na_avian': 516, 'swine': 39, 'human': 54, 'equine': 101, 'canine': 324}

# %%
# fitness analysis FET

p_values = []
odds_ratios = []
confidence = []


for clade in clades:
    a = rea_fits[clade]
    b = clonal_fits[clade]
    c = rea_unfits[clade]
    d = clonal_unfits[clade]

    table = [[a, b], [c, d]]

    odds_ratio, p_value = stats.fisher_exact(table, alternative='two-sided')

    if a > 0 and b > 0 and c > 0 and d > 0:
        se_log_or = math.sqrt(1/a + 1/b + 1/c + 1/d)
        log_or = math.log(odds_ratio)
        ci_low = math.exp(log_or - 1.96 * se_log_or)
        ci_high = math.exp(log_or + 1.96 * se_log_or)
    else:
        print(f"one of your counts for {clade} are 0")
        ci_low, ci_high = float('nan'), float('nan')
        
    odds_ratios.append(odds_ratio)
    p_values.append(p_value)
    confidence.append((ci_low, ci_high))

    print(f"{clade}: p-value = {p_value:.6f}, odds ratio = {odds_ratio:.2f}, 95% CI = {ci_low, ci_high}")
# Out:
# h3nx: p-value = 0.958279, odds ratio = 1.01, 95% CI = (0.8234415714927901, 1.241033534870448)
# na_avian: p-value = 0.442935, odds ratio = 1.11, 95% CI = (0.8467296345999521, 1.463028547225893)
# swine: p-value = 1.000000, odds ratio = 1.17, 95% CI = (0.3386657913295556, 4.042038006336234)
# one of your counts for human are 0
# human: p-value = 0.551671, odds ratio = inf, 95% CI = (nan, nan)
# equine: p-value = 1.000000, odds ratio = 0.84, 95% CI = (0.0519830861484131, 13.627562929897408)
# canine: p-value = 0.546448, odds ratio = 1.67, 95% CI = (0.1498216702147142, 18.617095487773394)

# %%
for clade, odds_ratio, p_value, (ci_low, ci_high) in zip(clades, odds_ratios, p_values, confidence):
    plt.figure(figsize=(4, 6))

    plt.errorbar(
        x=0,
        y=odds_ratio,
        yerr=[[odds_ratio - ci_low], [ci_high - odds_ratio]],
        fmt='o',
        color='tab:blue',
        capsize=5,
        label=f'p = {p_value:.3f}'
    )

    plt.axhline(1, color='gray', linestyle='--')  # neutral OR
    plt.xticks([0], [clade])  # show label on x-axis
    plt.ylabel('Odds Ratio')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
num_clades = len(clades)
fig, axes = plt.subplots(1, num_clades, figsize=(num_clades * 3, 6), sharey=True)

for ax, clade, odds_ratio, p_value, (ci_low, ci_high) in zip(
        axes, clades, odds_ratios, p_values, confidence):

    lower_err = odds_ratio - ci_low
    upper_err = ci_high - odds_ratio
    error_bars = [[lower_err], [upper_err]]

    ax.errorbar(
        [0], [odds_ratio],
        yerr=error_bars,
        fmt='o',
        color='darkcyan',
        ecolor='darkgrey',
        elinewidth=2,
        capsize=4,
        markersize=10
    )

    ax.axhline(1, color='black', linestyle='--')

    ax.set_xticks([0])
    ax.set_xticklabels([clade], rotation=45, ha='right')
    ax.set_xlim(-1, 1)

    ax.legend([f"p = {p_value:.3f}"], loc='upper right', frameon=False)

axes[0].set_ylabel("Odds Ratio")

plt.tight_layout()
plt.show()
