# %%
import pandas as pd
import os
import re
import sys

module_dir = "/Users/monclalab1/Documents/scripts/"
sys.path.append(module_dir)

from fasta_editing import fasta_to_df, fasta_writer

# %%
# take in alignment files and change to be strain|date for treesort (using metadata)
# divergence trees other files will be made using snakemake

def aln_metadata_prep(list_of_genes, home_folder, align_path, 
                  metadata_path, output_dir):

    
    for path in [f"{output_dir}/alignments", f"{output_dir}/metadata"]:
            if not os.path.exists(path):
                os.makedirs(path)
            else:
                pass
            
    strains = pd.read_csv(f"{home_folder}/strains.tsv", "\t")
    strains_set = set(strains["strain"]) 
    
    print(strains_set)
    
    for gene in list_of_genes:
        
        metadata_file = f"{home_folder}/{metadata_path}/metadata_h3nx_{gene}.tsv"

        align_file = f"{home_folder}/{align_path}/h3nx_{gene}.fasta"
        output_align = f"{output_dir}/alignments/h3nx_{gene}.fasta"
        
        # metadata file
        metadata = pd.read_csv(metadata_file, "\t")
        metadata["date"] = metadata["date"].str.replace('XX', '01')
        
        # alignment file 
        align = fasta_to_df(align_file)
        align.header = align.header.str.replace(">", "")
        
        align = align[align["header"].isin(strains_set)]

        merged = pd.merge(align, metadata[['strain', 'date']], left_on='header', right_on='strain', how='left')
        
        merged["header"] = merged[['strain', 'date']].apply('|'.join, axis=1)
        merged["header"] = ">" + merged["header"]
        
        fasta_writer(f"{output_dir}/alignments/", f"h3nx_{gene}.fasta", merged)
                 
        metadata["strain"] = metadata[['strain', 'date']].apply('|'.join, axis=1)

        metadata.to_csv(f"{output_dir}/metadata/h3nx_{gene}.csv", index=False)

# %%
list_of_genes = ["ha", "pb2","pb1","na","np","pa","ns","mp"]
aln_metadata_prep(list_of_genes, "preprepped", "aln", "meta", ".")
# Out:
# /var/folders/b4/087mzk6d6sj828w5t9xtml640000gr/T/ipykernel_91500/2848266220.py:14: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   strains = pd.read_csv(f"{home_folder}/strains.tsv", "\t")
# /var/folders/b4/087mzk6d6sj828w5t9xtml640000gr/T/ipykernel_91500/2848266220.py:27: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   metadata = pd.read_csv(metadata_file, "\t")
# /var/folders/b4/087mzk6d6sj828w5t9xtml640000gr/T/ipykernel_91500/2848266220.py:27: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   metadata = pd.read_csv(metadata_file, "\t")
# {'A/swine/Warendorf/6727/2007', 'A/swine/Indiana/21TOSU1301/2021', 'A/swine/Hong_Kong/NS2600/2014', 'A/swine/Minnesota/MT_12_07_518/2012', 'A/swine/Heilongjiang/1/05', 'A/swine/Iowa/A01432395/2013', 'A/swine/Thailand/PB483/2009', 'A/swine/Borken/21121/2015', 'A/swine/Indiana/18TOSU2186/2018', 'A/swine/Manitoba/01179/2006', 'A/swine/Chachoengsao/NIAH117865-035/2017', 'A/swine/Mexico/9783514/2013', 'A/swine/Italy/240849/2015', 'A/swine/North_Carolina/A02142700/2018', 'A/swine/Manitoba/D0255/2013', 'A/swine/Kagoshima/37-7194/2019', 'A/swine/Manitoba/G5/2014', 'A/swine/Louisiana/A02525266/2021', 'A/swine/Hanoi/8_745/2017', 'A/swine/North_Carolina/01216/2006', 'A/swine/Holtrup/6358/2007', 'A/swine/Lohne/17104/2013', 'A/swine/Ontario/G10/2014', 'A/swine/Minnesota/MT_13_01_S88/2013', 'A/swine/China/ZQ82/2018', 'A/swine/British_Columbia/28103/2005', 'A/swine/Manitoba/D0354/2014', 'A/swine/Stresow/7919a/2008', 'A/swine/Bad_Wuennenberg/7188/2008', 'A/swine/Manitoba/D0459/2016', 'A/swine/Manitoba/SD0251/2017', 'A/swine/Ohio/09SW65/2009', 'A/Swine/Shandong/3/2005/', 'A/swine/Texas/00226/2003', 'A/swine/Illinois/01131/2006', 'A/swine/Ontario/G12/2014', 'A/swine/Bac_Ninh/144/2012', 'A/swine/Chonburi/NIAH102952-058/2014', 'A/swine/Missouri/A02862345/2024', 'A/swine/Korea/CY03-12/2012', 'A/swine/Indiana/14TOSU0343/2014', 'A/swine/Vreden/5982/2007', 'A/swine/Chonburi/NIAH102952-086/2014', 'A/swine/Ohio/22TOSU3704/2022', 'A/swine/Chachoengsao/NIAH102215-095/2013', 'A/swine/North_Carolina/A02862272/2024', 'A/swine/Saskatchewan/SD0045/2014', 'A/swine/Hanoi/6_829/2016', 'A/swine/Hong_Kong/5047/2013', 'A/swine/Curico/VN1401-1806/2015', 'A/swine/Borgentreich/8083/2008', 'A/swine/Mexico/AVX37/2012', 'A/swine/Tainan/103-11/2003', 'A/swine/Bohmte/3856/2005', 'A/swine/Hungary/13509/2007', 'A/swine/Illinois/21TOSU2100/2021', 'A/swine/Arkansas/02863/2009', 'A/swine/Iowa/A01202614/2011', 'A/swine/Mexico/10499819/2014', 'A/swine/Goldenstedt/8310a/2008', 'A/swine/Indiana/18TOSU2860/2018', 'A/swine/Ohio/09SW99/2009', 'A/Swine/Cambodia/Chranieng/200502/2012/H3N2', 'A/swine/Hong_Kong/1197/02', 'A/swine/QC/382/2009', 'A/swine/Hanoi/8_509/2017', 'A/swine/Mexico/AVX60/2013', 'A/swine/Quebec/1561816/2014', 'A/swine/Italy/1103/2015', 'A/swine/Bac_Ninh/156/2012', 'A/swine/Italy/100176-1/2013', 'A/swine/Hong_Kong/NS3030/2011', 'A/swine/Hong_Kong/4995/2015', 'A/swine/Oklahoma/SG1216/2005', 'A/swine/Shandong/3/2005', 'A/swine/Leningrad_region/RII-6MS/2023', 'A/swine/Germany/R1341/2014', 'A/swine/Alberta/SD0172/2016', 'A/swine/Chiba/1-5640/2018', 'A/swine/Guangdong/968/2006', 'A/swine/Indiana/17TOSU2855/2017', 'A/swine/Hong_Kong/NS2818/2011', 'A/swine/Dong_Nai/12-07-3/2015', 'A/swine/Indiana/A01812061/2015', 'A/swine/Steinfurt/14736/2012', 'A/swine/Ontario/120-55/2012', 'A/swine/Guangdong/NS2893/2012', 'A/swine/Minnesota/01862/2007', 'A/swine/Iowa/13H092/2013', 'A/swine/Minnesota/080470/2015', 'A/swine/Ohio/09SW83E/2009', 'A/swine/Chonburi/NIAH102952-099/2014', 'A/swine/Manitoba/D0508/2017', 'A/swine/Brabant/1984', 'A/swine/Indiana/22TOSU3194/2022', 'A/swine/Ohio/OH19-21531-5/2019', 'A/swine/Guangxi/JG1/2014', 'A/swine/Indiana/24TOSU0771/2024', 'A/swine/Chiba/1-4250/2017', 'A/swine/Alberta/SD0109/2015', 'A/swine/North_Carolina/SG1230/2005', 'A/swine/Hong_Kong/NS2813/2011', 'A/swine/Iowa/A02861980/2023', 'A/swine/Ohio/16TOSU5381/2016', 'A/swine/Binh_Duong/03_09/2010', 'A/swine/Guangdong/NS2892/2012', 'A/swine/North_Carolina/00950/2006', 'A/swine/Italy/348315/2014', 'A/swine/Hong_Kong/1514/2013', 'A/swine/Minnesota/A01049936/2011', 'A/swine/Ohio/17TOSU5114/2017', 'A/swine/Obihiro/10/1985', 'A/swine/Chachoengsao/NIAH105583-052-74/2012', 'A/swine/Texas/A02245368/2019', 'A/swine/Italy/323027/2017', 'A/swine/Chachoengsao/NIAH110029-094/2012', 'A/swine/Nebraska/4D-0114-P4/2014', 'A/swine/Bac_Ninh/396/2014', 'A/swine/Manitoba/SG1431/2008', 'A/swine/Missouri/A01410818/2013', 'A/swine/Guangdong/1232/2012', 'A/swine/Hong_Kong/7982/00', 'A/swine/Telgte/10014/2009', 'A/swine/Mexico/8 ...
# /var/folders/b4/087mzk6d6sj828w5t9xtml640000gr/T/ipykernel_91500/2848266220.py:27: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   metadata = pd.read_csv(metadata_file, "\t")
# /var/folders/b4/087mzk6d6sj828w5t9xtml640000gr/T/ipykernel_91500/2848266220.py:27: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   metadata = pd.read_csv(metadata_file, "\t")
# /var/folders/b4/087mzk6d6sj828w5t9xtml640000gr/T/ipykernel_91500/2848266220.py:27: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   metadata = pd.read_csv(metadata_file, "\t")
# /var/folders/b4/087mzk6d6sj828w5t9xtml640000gr/T/ipykernel_91500/2848266220.py:27: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   metadata = pd.read_csv(metadata_file, "\t")
# /var/folders/b4/087mzk6d6sj828w5t9xtml640000gr/T/ipykernel_91500/2848266220.py:27: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   metadata = pd.read_csv(metadata_file, "\t")
# /var/folders/b4/087mzk6d6sj828w5t9xtml640000gr/T/ipykernel_91500/2848266220.py:27: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   metadata = pd.read_csv(metadata_file, "\t")
